# %% [markdown]
# # Selecting Rows and Columns in pandas

# %% [markdown]
# ### 1. Reading Data
# We first import `pandas` and load a table into a DataFrame.

# %%
import pandas as pd

df = pd.read_csv('data/population.csv', index_col=0)

# %% [markdown]
# ### 2. Attributes and Methods
#
# `.shape` is an *attribute*. It can be used with any dataset using a dot. It shows the number of rows and columns in a DataFrame as a Python *tuple*:

# %%
df.shape
# Out:
# (275, 81)

# %% [markdown]
# `.head()` is a *method*. It can be called on any DataFrame object by the dot, followed by parentheses.
# It returns the first N rows of the DataFrame.

# %%
df.head(3)
# Out:
#                             1800       1810       1820       1830       1840  \
# Total population
# Abkhazia                     NaN        NaN        NaN        NaN        NaN
# Afghanistan            3280000.0  3280000.0  3323519.0  3448982.0  3625022.0
# Akrotiri and Dhekelia        NaN        NaN        NaN        NaN        NaN
#
#                             1850       1860       1870       1880       1890  \
# Total population
# Abkhazia                     NaN        NaN        NaN        NaN        NaN
# Afghanistan            3810047.0  3973968.0  4169690.0  4419695.0  4710171.0
# Akrotiri and Dhekelia        NaN        NaN        NaN        NaN        NaN
#
#                        ...        2006        2007        2008        2009  \
# Total population       ...
# Abkhazia               ...         NaN         NaN         NaN         NaN
# Afghanistan            ...  25183615.0  25877544.0  26528741.0  27207291.0
# Akrotiri and Dhekelia  ...     15700.0     15700.0     15700.0         NaN
#
#                              2010        2011        2012        2013  \
# Total population
# Abkhazia                      NaN         NaN         NaN         NaN
# Afghanistan            27962207.0  28809167.0  29726803.0  30682500.0
# Akrotiri and Dhekelia         NaN         NaN         NaN         NaN
#
#                              2014        2015
# Total population
# Abkhazia                      NaN         NaN
# Afghanistan            31627506.0  32526562.0
# Akrotiri and Dhekelia         NaN         NaN
#
# [3 rows x 81 columns]

# %% [markdown]
# ### 3. Selecting Rows and Columns
# Match the Python commands with the descriptions below.
#
# * remove rows with missing values
#
# Create new Markdown cells in the notebook to have a heading for each command.

# %%
df.dropna(inplace=True)

# %% [markdown]
# * select a single row

# %%
df.iloc[[0]]
df.loc[['Afghanistan']]
# Out:
#                        1800       1810       1820       1830       1840  \
# Total population
# Afghanistan       3280000.0  3280000.0  3323519.0  3448982.0  3625022.0
#
#                        1850       1860       1870       1880       1890  ...  \
# Total population                                                         ...
# Afghanistan       3810047.0  3973968.0  4169690.0  4419695.0  4710171.0  ...
#
#                         2006        2007        2008        2009        2010  \
# Total population
# Afghanistan       25183615.0  25877544.0  26528741.0  27207291.0  27962207.0
#
#                         2011        2012        2013        2014        2015
# Total population
# Afghanistan       28809167.0  29726803.0  30682500.0  31627506.0  32526562.0
#
# [1 rows x 81 columns]

# %% [markdown]
# * inspect column labels

# %%
df.columns = df.columns.astype(int)

# %%
df.columns.dtype
# Out:
# dtype('int64')

# %% [markdown]
# * select multiple columns

# %%
df[[1800,2001]]
# Out:
#                             1800        2001
# Total population
# Afghanistan            3280000.0  20531160.0
# Albania                 410445.0   3124093.0
# Algeria                2503218.0  31590320.0
# American Samoa            8170.0     58176.0
# Andorra                   2654.0     67770.0
# ...                          ...         ...
# Virgin Islands (U.S.)    40000.0    108509.0
# Yemen                  2593000.0  18306287.0
# Zambia                  747000.0  10861238.0
# Zimbabwe               1085814.0  12603988.0
# South Sudan            1027378.0   6967817.0
#
# [229 rows x 2 columns]

# %% [markdown]
# * select rows by position

# %%
df.loc[['India', 'China']]
# Out:
#                          1800         1810         1820         1830  \
# Total population
# India             168574895.0  171940819.0  176225709.0  182214537.0
# China             321675013.0  350542958.0  380055273.0  402373519.0
#
#                          1840         1850         1860         1870  \
# Total population
# India             189298397.0  196657653.0  204966302.0  213725049.0
# China             411213424.0  402711280.0  380047548.0  363661158.0
#
#                          1880         1890  ...          2006          2007  \
# Total population                            ...
# India             223020377.0  232819584.0  ...  1.162088e+09  1.179686e+09
# China             365544192.0  377135349.0  ...  1.312601e+09  1.319625e+09
#
#                           2008          2009          2010          2011  \
# Total population
# India             1.197070e+09  1.214182e+09  1.230985e+09  1.247446e+09
# China             1.326691e+09  1.333807e+09  1.340969e+09  1.348174e+09
#
#                           2012          2013          2014          2015
# Total population
# India             1.263590e+09  1.279499e+09  1.295292e+09  1.311051e+09
# China             1.355387e+09  1.362514e+09  1.369436e+09  1.376049e+09
#
# [2 rows x 81 columns]

# %% [markdown]
# * select rows that match a condition

# %%
df[df[1800]>1000000]
# Out:
#                         1800        1810        1820        1830        1840  \
# Total population
# Afghanistan        3280000.0   3280000.0   3323519.0   3448982.0   3625022.0
# Algeria            2503218.0   2595056.0   2713079.0   2880355.0   3082721.0
# Angola             1567028.0   1567028.0   1597530.0   1686390.0   1813100.0
# Austria            3205587.0   3286650.0   3391206.0   3538286.0   3728381.0
# Bangladesh        19227358.0  19611269.0  20122865.0  20872777.0  21776468.0
# ...                      ...         ...         ...         ...         ...
# Uzbekistan         1919159.0   1919159.0   1966716.0   2106508.0   2308592.0
# Vietnam            6551000.0   6551000.0   6719340.0   7214925.0   7933037.0
# Yemen              2593000.0   2593000.0   2605438.0   2640779.0   2689275.0
# Zimbabwe           1085814.0   1085814.0   1106634.0   1167259.0   1253642.0
# South Sudan        1027378.0   1041076.0   1063732.0   1103246.0   1153401.0
#
#                         1850        1860        1870        1880        1890  \
# Total population
# Afghanistan        3810047.0   3973968.0   4169690.0   4419695.0   4710171.0
# Algeria            3299305.0   3536468.0   3811028.0   4143163.0   4525691.0
# Angola             1949329.0   2110747.0   2285417.0   2473597.0   2677047.0
# Austria            3962619.0   4235926.0   4556658.0   4947026.0   5408503.0
# Bangladesh        22719284.0  23665237.0  24757994.0  26094931.0  27615079.0
# ...                      ...         ...         ...         ...         ...
# Uzbekistan         2530062.0   2812219.0   3125228.0   3470567.0   3853133.0
# Vietnam            8722624.0   9411019.0  10284238.0  11472739.0  12934886.0
# Yemen              2738662.0   2796168.0   2866728.0   2960773.0   3070113.0
# Zimbabwe           1346417.0   1444385.0   1549480.0   1661683.0   1781947.0
# South Sudan        1205835.0   1329906.0   1462765.0   1604755.0   1756589.0
#
#                   ...         2006         2007         2008         2009  \
# Total population  ...
# Afghanistan       ...   25183615.0   25877544.0   26528741.0   27207291.0
# Algeria           ...   33749328.0   34261971.0   34811059.0   35401790.0
# Angola            ...   18541467.0   19183907.0   19842251.0   20520103.0
# Austria           ...    8269372.0    8301290.0    8331465.0    8361362.0
# Bangladesh        ...  144839238.0  146592687.0  148252473.0  149905836.0
# ...               ...          ...          ...          ...          ...
# Uzbekistan        ...   26242947.0   26586701.0   26952719.0   27338109.0
# Vietnam           ...   84979667.0   85770717.0   86589342.0   87449021.0
# Yemen             ...   21093973.0   21701105.0   22322699.0   22954226.0
# Zimbabwe          ...   13127942.0   13297798.0   13495462.0   13720997.0
# South Sudan       ...    8445659.0    8815495.0    9208598.0    9623176.0
#
#                          2010         2011         2012         2013  \
# Total population
# Afghanistan        27962207.0   28809167.0   29726803.0   30682500.0
# Algeria            36036159.0   36717132.0   37439427.0   38186135.0
# Angola             21219954.0   21942296.0   22685632.0   23448202.0
# Austria             8391986.0    8423559.0    8455477.0    8486962.0
# Bangladesh        151616777.0  153405612.0  155257387.0  157157394.0
# ...                       ...          ...          ...          ...
# Uzbekistan         27739764.0   28158395.0   28592451.0   29033361.0
# Vietnam            88357775.0   89321903.0   90335547.0   91378752.0
# Yemen              23591972.0   24234940.0   24882792.0   25533217.0
# Zimbabwe           13973897.0   14255592.0   14565482.0   14898092.0
# South Sudan        10056475.0   10510122.0   10980623.0   11453810.0
#
#                          2014         2015
# Total population
# Afghanistan        31627506.0   32526562.0
# Algeria            38934334.0   39666519.0
# Angola             24227524.0   25021974.0
# Austria             8516916.0    8544586.0
# Bangladesh        159077513.0  160995642.0
# ...                       ...          ...
# Uzbekistan         29469913.0   29893488.0
# Vietnam            92423338.0   93447601.0
# Yemen              26183676.0   26832215.0
# Zimbabwe           15245855.0   15602751.0
# South Sudan        11911184.0   12339812.0
#
# [80 rows x 81 columns]

# %% [markdown]
# * select multiple rows

# %%
df.iloc[1:3,4:15]
# Out:
#                        1840       1850       1860       1870       1880  \
# Total population
# Albania            478227.0   506889.0   552800.0   610036.0   672544.0
# Algeria           3082721.0  3299305.0  3536468.0  3811028.0  4143163.0
#
#                        1890       1900       1910       1920       1930  \
# Total population
# Albania            741688.0   819950.0   901122.0   963956.0  1015991.0
# Algeria           4525691.0  4946166.0  5404045.0  6063800.0  6876190.0
#
#                        1940
# Total population
# Albania           1123210.0
# Algeria           7797418.0

# %% [markdown]
# * select a single column

# %%
df[[1800]]
# Out:
#                             1800
# Total population
# Afghanistan            3280000.0
# Albania                 410445.0
# Algeria                2503218.0
# American Samoa            8170.0
# Andorra                   2654.0
# ...                          ...
# Virgin Islands (U.S.)    40000.0
# Yemen                  2593000.0
# Zambia                  747000.0
# Zimbabwe               1085814.0
# South Sudan            1027378.0
#
# [229 rows x 1 columns]

# %% [markdown]
# * select values in a given range

# %%
df[df[2015].between(100_000_000,2_000_000_000)]
# Out:
#                          1800         1810         1820         1830  \
# Total population
# Bangladesh         19227358.0   19611269.0   20122865.0   20872777.0
# Philippines       9.029712e+07  9.164188e+07  9.303890e+07  9.450123e+07
# Russia            1.431232e+08  1.431267e+08  1.431581e+08  1.432115e+08
# United States     3.044731e+08  3.072320e+08  3.098762e+08  3.123904e+08
#
#                           2012          2013          2014          2015
# Total population
# Bangladesh        1.552574e+08  1.571574e+08  1.590775e+08  1.609956e+08
# Brazil            2.024016e+08  2.042594e+08  2.060779e+08  2.078475e+08
# China             1.355387e+09  1.362514e+09  1.369436e+09  1.376049e+09
# India             1.263590e+09  1.279499e+09  1.295292e+09  1.311051e+09
# Indonesia         2.480379e+08  2.512683e+08  2.544548e+08  2.575638e+08
# Japan             1.271398e+08  1.269850e+08  1.267946e+08  1.265735e+08
# Mexico            1.220710e+08  1.237401e+08  1.253858e+08  1.270172e+08
# Nigeria           1.682404e+08  1.728165e+08  1.774760e+08  1.822020e+08
# Pakistan          1.773923e+08  1.811926e+08  1.850443e+08  1.889249e+08
# Philippines       9.601732e+07  9.757168e+07  9.913869e+07  1.006994e+08
# Russia            1.432875e+08  1.433673e+08  1.434294e+08  1.434569e+08
# United States     3.147995e+08  3.171359e+08  3.194486e+08  3.217736e+08
#
# [12 rows x 81 columns]

# %% [markdown]
# * select rows and columns by position

# %%
df.iloc[4:6,10:20]
# Out:
#                        1900       1910       1920       1930       1940  \
# Total population
# Andorra              4393.0     4671.0     4974.0     5309.0     5667.0
# Angola            2898155.0  3136718.0  3387663.0  3642200.0  3920011.0
#
#                        1950       1951       1952       1953       1954
# Total population
# Andorra              6197.0     6692.0     7250.0     7863.0     8526.0
# Angola            4354882.0  4439705.0  4529381.0  4621691.0  4714970.0

# %% [markdown]
# * inspect row labels

# %%
df.index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia',
#        ...
#        'Vanuatu', 'Venezuela', 'West Bank and Gaza', 'Western Sahara',
#        'Vietnam', 'Virgin Islands (U.S.)', 'Yemen', 'Zambia', 'Zimbabwe',
#        'South Sudan'],
#       dtype='object', name='Total population', length=229)

# %% [markdown]
# * select rows and columns

# %%
df.loc[['Angola'], ]
# Out:
#                        1800       1810       1820       1830       1840  \
# Total population
# Angola            1567028.0  1567028.0  1597530.0  1686390.0  1813100.0
#
#                        1850       1860       1870       1880       1890  ...  \
# Total population                                                         ...
# Angola            1949329.0  2110747.0  2285417.0  2473597.0  2677047.0  ...
#
#                         2006        2007        2008        2009        2010  \
# Total population
# Angola            18541467.0  19183907.0  19842251.0  20520103.0  21219954.0
#
#                         2011        2012        2013        2014        2015
# Total population
# Angola            21942296.0  22685632.0  23448202.0  24227524.0  25021974.0
#
# [1 rows x 81 columns]

# %%
df.iloc[[14,50], [5,50]]
# Out:
#                        1850       1985
# Total population
# Austria           3962619.0  7600514.0
# Congo, Rep.        391323.0  2083648.0

# %%
df.iloc[3:5,:]
# Out:
#                        1800       1810       1820       1830       1840  \
# Total population
# Albania            410445.0   423591.0   438671.0   457234.0   478227.0
# Algeria           2503218.0  2595056.0  2713079.0  2880355.0  3082721.0
#
#                        1850       1860       1870       1880       1890  ...  \
# Total population                                                         ...
# Albania            506889.0   552800.0   610036.0   672544.0   741688.0  ...
# Algeria           3299305.0  3536468.0  3811028.0  4143163.0  4525691.0  ...
#
#                         2006        2007        2008        2009        2010  \
# Total population
# Albania            3050741.0   3010849.0   2968026.0   2929886.0   2901883.0
# Algeria           33749328.0  34261971.0  34811059.0  35401790.0  36036159.0
#
#                         2011        2012        2013        2014        2015
# Total population
# Albania            2886010.0   2880667.0   2883281.0   2889676.0   2896679.0
# Algeria           36717132.0  37439427.0  38186135.0  38934334.0  39666519.0
#
# [2 rows x 81 columns]

# %%
help(df.iloc)
# Out:
# Help on _iLocIndexer in module pandas.core.indexing object:
#
# class _iLocIndexer(_LocationIndexer)
#  |  Purely integer-location based indexing for selection by position.
#  |
#  |  ``.iloc[]`` is primarily integer position based (from ``0`` to
#  |  ``length-1`` of the axis), but may also be used with a boolean
#  |  array.
#  |
#  |  Allowed inputs are:
#  |
#  |  - An integer, e.g. ``5``.
#  |  - A list or array of integers, e.g. ``[4, 3, 0]``.
#  |  - A slice object with ints, e.g. ``1:7``.
#  |  - A boolean array.
#  |  - A ``callable`` function with one argument (the calling Series or
#  |    DataFrame) and that returns valid output for indexing (one of the above).
#  |    This is useful in method chains, when you don't have a reference to the
#  |    calling object, but would like to base your selection on some value.
#  |  - A tuple of row and column indexes. The tuple elements consist of one of the
#  |    above inputs, e.g. ``(0, 1)``.
#  |
#  |  ``.iloc`` will raise ``IndexError`` if a requested indexer is
#  |  out-of-bounds, except *slice* indexers which allow out-of-bounds
#  |  indexing (this conforms with python/numpy *slice* semantics).
#  |
#  |  See more at :ref:`Selection by Position <indexing.integer>`.
#  |
#  |  See Also
#  |  --------
#  |  DataFrame.iat : Fast integer location scalar accessor.
#  |  DataFrame.loc : Purely label-location based indexer for selection by label.
#  |  Series.iloc : Purely integer-location based indexing for
#  |                 selection by position.
#  |
#  |  Examples
#  |  --------
#  |  >>> mydict = [{'a': 1, 'b': 2, 'c': 3, 'd': 4},
#  |  ...           {'a': 100, 'b': 200, 'c': 300, 'd': 400},
#  |  ...           {'a': 1000, 'b': 2000, 'c': 3000, 'd': 4000 }]
#  |  >>> df = pd.DataFrame(mydict)
#  |  >>> df
#  |        a     b     c     d
#  |  0     1     2     3     4
#  |  1   100   200   300   400
#  |  2  1000  2000  3000  4000
#  |
#  |  **Indexing just the rows**
#  |
#  |  With a scalar integer.
#  |
#  |  >>> type(df.iloc[0])
#  |  <class 'pandas.core.series.Series'>
#  |  >>> df.iloc[0]
#  |  a    1
#  |  b    2
#  |  c    3
#  |  d    4
#  |  Name: 0, dtype: int64
#  |
#  |  With a list of integers.
#  |
#  |  >>> df.iloc[[0]]
#  |     a  b  c  d
#  |  0  1  2  3  4
#  |  >>> type(df.iloc[[0]])
#  |  <class 'pandas.core.frame.DataFrame'>
#  |
#  |  >>> df.iloc[[0, 1]]
#  |       a    b    c    d
#  |  0    1    2    3    4
#  |  1  100  200  300  400
#  |
#  |  With a `slice` object.
#  |
#  |  >>> df.iloc[:3]
#  |        a     b     c     d
#  |  0     1     2     3     4
#  |  1   100   200   300   400
#  |  2  1000  2000  3000  4000
#  |
#  |  With a boolean mask the same length as the index.
#  |
#  |  >>> df.iloc[[True, False, True]]
#  |        a     b     c     d
#  |  0     1     2     3     4
#  |  2  1000  2000  3000  4000
#  |
#  |  With a callable, useful in method chains. The `x` passed
#  |  to the ``lambda`` is the DataFrame being sliced. This selects
#  |  the rows whose index label even.
#  |
#  |  >>> df.iloc[lambda x: x.index % 2 == 0]
#  |        a     b     c     d
#  |  0     1     2     3     4
#  |  2  1000  2000  3000  4000
#  |
#  |  **Indexing both axes**
#  |
#  |  You can mix the indexer types for the index and columns. Use ``:`` to
#  |  select the entire axis.
#  |
#  |  With scalar integers.
#  |
#  |  >>> df.iloc[0, 1]
#  |  2
#  |
#  |  With lists of integers.
#  |
#  |  >>> df.iloc[[0, 2], [1, 3]]
#  |        b     d
#  |  0     2     4
#  |  2  2000  4000
#  |
#  |  With `slice` objects.
#  |
#  |  >>> df.iloc[1:3, 0:3]
#  |        a     b     c
#  |  1   100   200   300
#  |  2  1000  2000  3000
#  |
#  |  With a boolean array whose length matches the columns.
#  |
#  |  >>> df.iloc[:, [True, False, True, False]]
#  |        a     c
#  |  0     1     3
#  |  1   100   300
#  |  2  1000  3000
#  |
#  |  With a callable function that expects the Series or DataFrame.
#  |
#  |  >>> df.iloc[:, lambda df: [0, 2]]
#  |        a     c
#  |  0     1     3
#  |  1   100   300
#  |  2  1000  3000
#  |
#  |  Method resolution order:
#  |      _iLocIndexer
#  |      _LocationIndexer
#  |      pandas._libs.indexing.NDFrameIndexerBase
#  |      builtins.object
#  |
#  |  Data and other attributes defined here:
#  |
#  |  __annotations__ = {}
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from _LocationIndexer:
#  |
#  |  __call__(self, axis: 'Axis | None' = None) -> 'Self'
#  |      Call self as a function.
#  |
#  |  __getitem__(self, key)
#  |
#  |  __setitem__(self, key, value) -> 'None'
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from _LocationIndexer:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from _LocationIndexer:
#  |
#  |  axis = None
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from pandas._libs.indexing.NDFrameIndexerBase:
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __reduce__ = __reduce_cython__(...)
#  |
#  |  __setstate__ = __setstate_cython__(...)
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from pandas._libs.indexing.NDFrameIndexerBase:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from pandas._libs.indexing.NDFrameIndexerBase:
#  |
#  |  name
#  |
#  |  ndim
#  |
#  |  obj

# %%
df.loc[['Afghanistan', 'India'], ['1800', '2001']]
# Out:
#                          1800          2001
# Total population
# Afghanistan         3280000.0  2.053116e+07
# India             168574895.0  1.071888e+09

# %%
df.iloc[[1,2,3],[1,2,3]]
# Out:
#                             1810       1820       1830
# Total population
# Afghanistan            3280000.0  3323519.0  3448982.0
# Akrotiri and Dhekelia        NaN        NaN        NaN
# Albania                 423591.0   438671.0   457234.0

# %%
df.index
# Out:
# Index(['Abkhazia', 'Afghanistan', 'Akrotiri and Dhekelia', 'Albania',
#        'Algeria', 'American Samoa', 'Andorra', 'Angola', 'Anguilla',
#        'Antigua and Barbuda',
#        ...
#        'British Indian Ocean Territory', 'Clipperton',
#        'French Southern and Antarctic Lands', 'Gaza Strip',
#        'Heard and McDonald Islands', 'Northern Marianas',
#        'South Georgia and the South Sandwich Islands',
#        'US Minor Outlying Islands', 'Virgin Islands', 'West Bank'],
#       dtype='object', name='Total population', length=275)

# %%
df.columns
# Out:
# Index(['1800', '1810', '1820', '1830', '1840', '1850', '1860', '1870', '1880',
#        '1890', '1900', '1910', '1920', '1930', '1940', '1950', '1951', '1952',
#        '1953', '1954', '1955', '1956', '1957', '1958', '1959', '1960', '1961',
#        '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970',
#        '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979',
#        '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988',
#        '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015'],
#       dtype='object')

# %%
df['2015']
# Out:
# Total population
# Abkhazia                                               NaN
# Afghanistan                                     32526562.0
# Akrotiri and Dhekelia                                  NaN
# Albania                                          2896679.0
# Algeria                                         39666519.0
#                                                    ...
# Northern Marianas                                      NaN
# South Georgia and the South Sandwich Islands           NaN
# US Minor Outlying Islands                              NaN
# Virgin Islands                                         NaN
# West Bank                                              NaN
# Name: 2015, Length: 275, dtype: float64

# %%
df[['1900', '1950', '2000']]
# Out:
#                                                    1900       1950        2000
# Total population
# Abkhazia                                            NaN        NaN         NaN
# Afghanistan                                   5021241.0  7752118.0  19701940.0
# Akrotiri and Dhekelia                               NaN    10661.0     15157.0
# Albania                                        819950.0  1263171.0   3121965.0
# Algeria                                       4946166.0  8872247.0  31183658.0
# ...                                                 ...        ...         ...
# Northern Marianas                                   NaN        NaN         NaN
# South Georgia and the South Sandwich Islands        NaN        NaN         NaN
# US Minor Outlying Islands                           NaN        NaN         NaN
# Virgin Islands                                      NaN        NaN         NaN
# West Bank                                           NaN        NaN         NaN
#
# [275 rows x 3 columns]

# %%
df.loc['Estonia']
# Out:
# 1800     334136.0
# 1810     334136.0
# 1820     342427.0
# 1830     366799.0
# 1840     402035.0
#           ...
# 2011    1328068.0
# 2012    1324040.0
# 2013    1320050.0
# 2014    1316203.0
# 2015    1312558.0
# Name: Estonia, Length: 81, dtype: float64

# %%
df.loc[['Japan', 'China', 'Brazil']]
# Out:
#                          1800         1810         1820         1830  \
# Total population
# Japan              30294378.0   30645903.0   30993147.0   31330455.0
# China             321675013.0  350542958.0  380055273.0  402373519.0
# Brazil              3639636.0    4058652.0    4582325.0    5301068.0
#
#                          1840         1850         1860         1870  \
# Total population
# Japan              31663783.0   32223184.0   33176900.0   34638021.0
# China             411213424.0  402711280.0  380047548.0  363661158.0
# Brazil              6206694.0    7254194.0    8466005.0    9964419.0
#
#                          1880         1890  ...          2006          2007  \
# Total population                            ...
# Japan              36826469.0   39878734.0  ...  1.271366e+08  1.272500e+08
# China             365544192.0  377135349.0  ...  1.312601e+09  1.319625e+09
# Brazil             11893392.0   14410738.0  ...  1.906982e+08  1.927845e+08
#
#                           2008          2009          2010          2011  \
# Total population
# Japan             1.273179e+08  1.273409e+08  1.273198e+08  1.272529e+08
# China             1.326691e+09  1.333807e+09  1.340969e+09  1.348174e+09
# Brazil            1.947697e+08  1.967013e+08  1.986142e+08  2.005176e+08
#
#                           2012          2013          2014          2015
# Total population
# Japan             1.271398e+08  1.269850e+08  1.267946e+08  1.265735e+08
# China             1.355387e+09  1.362514e+09  1.369436e+09  1.376049e+09
# Brazil            2.024016e+08  2.042594e+08  2.060779e+08  2.078475e+08
#
# [3 rows x 81 columns]

# %%
df.loc['Croatia', '2000']
# Out:
# 4428069.0

# %%
df.iloc[10:15]
# Out:
#                        1800       1810       1820       1830       1840  \
# Total population
# Argentina          534000.0   534000.0   570719.0   686703.0   873747.0
# Armenia            413326.0   413326.0   423527.0   453507.0   496835.0
# Aruba               19286.0    19286.0    19555.0    20332.0    21423.0
# Australia          351014.0   342440.0   334002.0   348143.0   434095.0
# Austria           3205587.0  3286650.0  3391206.0  3538286.0  3728381.0
#
#                        1850       1860       1870       1880       1890  ...  \
# Total population                                                         ...
# Argentina         1113189.0  1421333.0  1856886.0  2493156.0  3402273.0  ...
# Armenia            544302.0   595928.0   652450.0   713957.0   781218.0  ...
# Aruba               22574.0    23786.0    25063.0    26404.0    27817.0  ...
# Australia          742619.0  1256048.0  1724213.0  2253007.0  3088808.0  ...
# Austria           3962619.0  4235926.0  4556658.0  4947026.0  5408503.0  ...
#
#                         2006        2007        2008        2009        2010  \
# Total population
# Argentina         39558750.0  39969903.0  40381860.0  40798641.0  41222875.0
# Armenia            3002161.0   2988117.0   2975029.0   2966108.0   2963496.0
# Aruba               100830.0    101218.0    101342.0    101416.0    101597.0
# Australia         20606228.0  20975949.0  21370348.0  21770690.0  22162863.0
# Austria            8269372.0   8301290.0   8331465.0   8361362.0   8391986.0
#
#                         2011        2012        2013        2014        2015
# Total population
# Argentina         41655616.0  42095224.0  42538304.0  42980026.0  43416755.0
# Armenia            2967984.0   2978339.0   2992192.0   3006154.0   3017712.0
# Aruba               101936.0    102393.0    102921.0    103441.0    103889.0
# Australia         22542371.0  22911375.0  23270465.0  23622353.0  23968973.0
# Austria            8423559.0   8455477.0   8486962.0   8516916.0   8544586.0
#
# [5 rows x 81 columns]

# %%
df.iloc[10:15, 75:]
# Out:
#                         2010        2011        2012        2013        2014  \
# Total population
# Argentina         41222875.0  41655616.0  42095224.0  42538304.0  42980026.0
# Armenia            2963496.0   2967984.0   2978339.0   2992192.0   3006154.0
# Aruba               101597.0    101936.0    102393.0    102921.0    103441.0
# Australia         22162863.0  22542371.0  22911375.0  23270465.0  23622353.0
# Austria            8391986.0   8423559.0   8455477.0   8486962.0   8516916.0
#
#                         2015
# Total population
# Argentina         43416755.0
# Armenia            3017712.0
# Aruba               103889.0
# Australia         23968973.0
# Austria            8544586.0

# %%
df.loc[df['2000'] > 200_000_000]
# Out:
#                          1800         1810         1820         1830  \
# Total population
# China             321675013.0  350542958.0  380055273.0  402373519.0
# India             168574895.0  171940819.0  176225709.0  182214537.0
# Indonesia          16108545.0   16537268.0   17236636.0   18460171.0
# United States       6801854.0    8294928.0   10361646.0   13480460.0
# USSR                      NaN          NaN          NaN          NaN
#
#                          1840         1850         1860         1870  \
# Total population
# China             411213424.0  402711280.0  380047548.0  363661158.0
# India             189298397.0  196657653.0  204966302.0  213725049.0
